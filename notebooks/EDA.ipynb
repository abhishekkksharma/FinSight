# %% [markdown]
# # Expense Prediction EDA
#
# This notebook is a lightweight companion to the automated EDA generated by `src/train.py`.

# %%
from pathlib import Path
import pandas as pd

data_path = Path('..') / 'data' / 'dataset.csv'
df = pd.read_csv(data_path)
df['Total_Expense'] = df[['Rent', 'Loan_Repayment', 'Insurance', 'Groceries', 'Transport']].sum(axis=1)
df.head()

# %%
df[['Income', 'Age', 'Dependents', 'Total_Expense']].describe()

# %%
df[['Occupation', 'City_Tier']].value_counts().head(20)
